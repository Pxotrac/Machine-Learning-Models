# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Mileage
# Dealer Name
# Rating
# Rating Count
# Price

# %% [markdown]
# #### Name

# %%
results[0].find('h2').get_text()
# Out:
# 'Certified 2022 Mercedes-Benz EQS 580 Base 4MATIC'

# %% [markdown]
# #### Mileage

# %%
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '4,746 mi.'

# %% [markdown]
# #### Dealer Name

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of Foothill Ranch'

# %% [markdown]
# #### Rating

# %%
rating_element = results[0].find('span', {'class':'sds-rating__count'})
rating = rating_element.get_text() if rating_element else 'N/A'

# %% [markdown]
# #### Review Count

# %%
review_count_element = results[0].find('span', {'class':'sds-rating__link'})
review_count = review_count_element.get_text() if review_count_element else 'N/A'

# %% [markdown]
# #### Price

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$84,996'

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:

    # name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('n/a')

    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')

    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')

    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')

    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')

    #price
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %% [markdown]
# ### Create Pandas Dataframe

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                                  Name     Mileage  \
# 0    Certified 2022 Mercedes-Benz EQS 580 Base 4MATIC   4,746 mi.
# 1               Certified 2020 Mercedes-Benz GLB 250   34,959 mi.
# 2   Certified 2020 Mercedes-Benz AMG GLC 43 Base 4...  21,111 mi.
# 3          Certified 2017 Mercedes-Benz C-Class C 300  67,802 mi.
# 4    Certified 2020 Mercedes-Benz GLS 450 Base 4MATIC  42,186 mi.
# 5   Certified 2023 Mercedes-Benz AMG GLS 63 Base 4...   3,721 mi.
# 6          Certified 2020 Mercedes-Benz E-Class E 450  50,756 mi.
# 7   Certified 2019 Mercedes-Benz S-Class S 450 4MATIC  56,382 mi.
# 12   Certified 2023 Mercedes-Benz CLA 250 Base 4MATIC   2,640 mi.
# 13         Certified 2020 Mercedes-Benz S-Class S 450  24,053 mi.
# 14   Certified 2022 Mercedes-Benz EQB 350 Base 4MATIC   4,064 mi.
# 15     Certified 2019 Mercedes-Benz AMG E 63 S 4MATIC  46,755 mi.
# 16  Certified 2023 Mercedes-Benz S-Class S 500 4MATIC   5,192 mi.
# 17          Certified 2020 Mercedes-Benz GLC 300 Base  18,372 mi.
# 18              Certified 2020 Mercedes-Benz AMG GT R   6,496 mi.
# 19  Certified 2021 Mercedes-Benz E-Class E 450 4MATIC  25,869 mi.
# 20          Certified 2019 Mercedes-Benz CLS 450 Base  40,474 mi.
#
#                         Dealer Name Rating Review Count     Price
# 0   Mercedes-Benz of Foothill Ranch    n/a          n/a   $84,996
# 1                               n/a    n/a          n/a   $31,209
# 2                               n/a    n/a          n/a   $47,599
# 3                               n/a    n/a          n/a   $19,994
# 4                               n/a    n/a          n/a   $57,995
# 5                               n/a    n/a          n/a  $138,996
# 6                               n/a    n/a          n/a   $46,991
# 7                               n/a    n/a          n/a   $43,997
# 8                               n/a    n/a          n/a   $59,993
# 9                               n/a    n/a          n/a   $81,999
# 10                              n/a    n/a          n/a   $74,000
# 11                              n/a    n/a          n/a   $48,980
# 12                              n/a    n/a          n/a   $40,999
# 13                              n/a    n/a          n/a   $58,480
# 14                              n/a    n/a          n/a   $49,997
# 15                              n/a    n/a          n/a   $73,998
# 16                              n/a    n/a          n/a  $106,999
# 17                              n/a    n/a          n/a   $35,623
# 18                              n/a    n/a          n/a  $178,996
# 19                              n/a    n/a          n/a   $49,613
# 20                              n/a    n/a          n/a   $43,268

# %% [markdown]
# ### Output in Excel

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %% [markdown]
# ### Part 2 - Pagination

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):

    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip='

    # request to website
    response = requests.get(website)

    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')

    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})

    # loop through results
    for result in results:

        # name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0       2022 Mercedes-Benz EQS 580 Base 4MATIC   4,746 mi.
# 1             2017 Mercedes-Benz C-Class C 300  67,802 mi.
# 2       2020 Mercedes-Benz GLS 450 Base 4MATIC  42,186 mi.
# 3    2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  21,111 mi.
# 4                  2020 Mercedes-Benz GLB 250   34,959 mi.
# ..                                         ...         ...
# 205  2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  35,384 mi.
# 206     2020 Mercedes-Benz GLS 450 Base 4MATIC  27,559 mi.
# 207     2020 Mercedes-Benz GLE 350 Base 4MATIC  98,989 mi.
# 208    2023 Mercedes-Benz E-Class E 350 4MATIC   2,971 mi.
# 209         2023 Mercedes-Benz AMG GLB 35 Base   2,833 mi.
#
#                          Dealer Name Rating     Review Count    Price
# 0    Mercedes-Benz of Foothill Ranch    n/a              n/a  $84,996
# 1      Mercedes-Benz of West Houston    4.6     (74 reviews)  $19,994
# 2                 D-Patrick Motoplex    4.7    (373 reviews)  $57,995
# 3         Mercedes-Benz of Littleton    4.8  (1,205 reviews)  $47,599
# 4       Mercedes-Benz of Baton Rouge    4.9    (849 reviews)  $31,209
# ..                               ...    ...              ...      ...
# 205     Bloomington Normal Auto-Mall    3.6    (143 reviews)  $43,593
# 206         Crown Eurocars of Dublin    4.9  (2,738 reviews)  $59,915
# 207        Mercedes-Benz of Columbia    5.0    (970 reviews)  $33,731
# 208    Mercedes-Benz of Owings Mills    4.9  (2,324 reviews)  $56,490
# 209                Autohaus on Edens    4.7  (2,632 reviews)  $58,210
#
# [210 rows x 6 columns]

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0       2022 Mercedes-Benz EQS 580 Base 4MATIC   4,746 mi.
# 1             2017 Mercedes-Benz C-Class C 300  67,802 mi.
# 2       2020 Mercedes-Benz GLS 450 Base 4MATIC  42,186 mi.
# 3    2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  21,111 mi.
# 4                  2020 Mercedes-Benz GLB 250   34,959 mi.
# ..                                         ...         ...
# 205  2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  35,384 mi.
# 206     2020 Mercedes-Benz GLS 450 Base 4MATIC  27,559 mi.
# 207     2020 Mercedes-Benz GLE 350 Base 4MATIC  98,989 mi.
# 208    2023 Mercedes-Benz E-Class E 350 4MATIC   2,971 mi.
# 209         2023 Mercedes-Benz AMG GLB 35 Base   2,833 mi.
#
#                          Dealer Name Rating Review Count    Price
# 0    Mercedes-Benz of Foothill Ranch    n/a          n/a  $84,996
# 1      Mercedes-Benz of West Houston    4.6          74   $19,994
# 2                 D-Patrick Motoplex    4.7         373   $57,995
# 3         Mercedes-Benz of Littleton    4.8       1,205   $47,599
# 4       Mercedes-Benz of Baton Rouge    4.9         849   $31,209
# ..                               ...    ...          ...      ...
# 205     Bloomington Normal Auto-Mall    3.6         143   $43,593
# 206         Crown Eurocars of Dublin    4.9       2,738   $59,915
# 207        Mercedes-Benz of Columbia    5.0         970   $33,731
# 208    Mercedes-Benz of Owings Mills    4.9       2,324   $56,490
# 209                Autohaus on Edens    4.7       2,632   $58,210
#
# [210 rows x 6 columns]
